# %% [markdown]
# ## Assignment II  Part 1 - Hurricanes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
hurricanes = pd.read_csv('Hurricanes.csv')

# %%
hurricanes.head()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4

# %%
hurricanes
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# ..    ...         ...
# 96   2010          12
# 97   2011           7
# 98   2012          10
# 99   2013           2
# 100  2014           6
#
# [101 rows x 2 columns]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
ax.set_title('Number of Hurricanes Across the Atlantic')
ax.set_ylabel('Number of Hurricanes')
ax.set_xlabel('Years')
x = hurricanes['Year']
y = hurricanes['Hurricanes']
ax.bar(x,y)
plt.show()

# %% [markdown]
# ## Assignment II Part 2 - City Temperatures

# %%
city_temps = pd.read_csv('CityTemps.csv')

# %%
city_temps.head()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5

# %%
city_temps
# Out:
#     Year  Month  Moscow  Melbourne  San Francisco
# 0   2014      1    -8.6       22.0           12.8
# 1   2014      2    -1.9       21.5           12.7
# 2   2014      3     2.8       19.5           15.0
# 3   2014      4     7.0       15.8           15.7
# 4   2014      5    16.0       13.9           17.5
# 5   2014      6    16.1       11.3           17.9
# 6   2014      7    21.1        9.9           19.4
# 7   2014      8    19.2       10.4           19.5
# 8   2014      9    12.3       12.8           20.2
# 9   2014     10     3.7       15.6           20.4
# 10  2014     11    -1.3       17.3           15.4
# 11  2014     12    -3.9       18.9           13.8
# 12  2015      1    -4.4       20.4           12.2
# 13  2015      2    -2.2       21.8           14.8
# 14  2015      3     2.0       17.4           15.7
# 15  2015      4     6.1       14.1           14.8
# 16  2015      5    14.2       12.6           14.7
# 17  2015      6    17.9        9.8           17.1
# ...

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
ax.set_title('City Temperatures - San Francisco')
ax.set_ylabel('Temperatures')
ax.set_xlabel('Years')
x = city_temps['Year']
y = city_temps['San Francisco']
ax.bar(x,y)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,2])
ax.set_title('City Temperatures - Moscow')
ax.set_ylabel('Temperatures')
ax.set_xlabel('Years')
x = city_temps['Year']
y = city_temps['Moscow']
ax.bar(x,y)
plt.show()

# %% [markdown]
# ## Assignment II Part 3 - Manufacturing

# %%
manu = pd.read_csv('Cars2015.csv')
manu
# Out:
#            Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0     Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1       Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2           Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3    Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4        Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
# ..          ...         ...        ...       ...        ...   ...      ...
# 105      Toyoto     Sequioa      7Pass    44.395     64.320   RWD       12
# 106      Nissan  Pathfinder      7Pass    29.510     43.100   FWD       19
# 107       Acura         MDX      7Pass    42.865     57.080   FWD       18
# 108     Hyundai    Santa Fe      7Pass    30.150     36.000   FWD       18
# 109        GMC        Yukon      7Pass    47.740     67.520   RWD       16
#
# ...

# %%
df = pd.read_csv('Cars2015.csv')
df = df.drop(['Model','Type','LowPrice','HighPrice','Drive','CityMPG','HwyMPG','FuelCap','Length'], axis=1)
df = df.drop(['Width','Wheelbase','Height','UTurn','Weight','Acc030','Acc060'],axis=1)
df = df.drop(['QtrMile','PageNum','Size'],axis=1)
df['count'] = df.groupby('Make')['Make'].transform('count')
df.drop_duplicates('Make',inplace=True)
df.sort_values(by='count',ascending=False,inplace=True)
plt.figure(figsize=(50,8))
ax1 = plt.subplot(121, aspect='equal')
df.plot(kind='pie', y = 'count', ax=ax1, autopct='%1.1f%%',startangle=90, shadow=False, labels=df['Make'], legend = False, fontsize=10) 
plt.show()

# %% [markdown]
# ## Assignment II Part 4

# %%
info_df = pd.read_csv('Info.csv') #Contains CSV data from Assignment 
info_df.head()
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price                 date
# 0       44.48     578.24  2014-09-27 07:13:03
# 1       53.62    1018.78  2014-07-29 02:10:44
# 2       24.16     289.92  2014-03-01 10:51:24
# 3       82.68     413.40  2013-11-17 20:41:11
# 4       99.64    1793.52  2014-01-03 08:14:27

# %%
#Describe the unitprice:
info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account_number  1000 non-null   int64
#  1   name            1000 non-null   object
#  2   item_code       1000 non-null   object
#  3   category        1000 non-null   object
#  4   quantity        1000 non-null   int64
#  5   unit price      1000 non-null   float64
#  6   net_price       1000 non-null   float64
#  7   date            1000 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
# Create anew DataFramehaving columnsasname,net_price,date,and group all the records according to name.
new_df = info_df[['name', 'net_price', 'date']].filter(['name', 'net_price', 'date']).groupby('name', as_index=False).sum()
new_df
# Out:
#                              name  net_price
# 0                       Berge LLC   30064.87
# 1                     Carroll PLC   35934.31
# 2                   Cole-Eichmann   30435.42
# 3      Davis, Kshlerin and Reilly   19054.76
# 4    Ernser, Cruickshank and Lind   28089.02
# 5                   Gorczany-Hahn   22207.90
# 6                  Hamill-Hackett   23433.78
# 7                Hegmann and Sons   35213.72
# 8               Heidenreich-Bosco   25428.29
# 9                       Huel-Haag   21087.88
# 10  Kerluke, Reilly and Bechtelar   27389.43
# 11      Kihn, McClure and Denesik   38935.29
# 12                Kilback-Gerlach   26987.20
# 13                    Koelpin PLC   26811.66
# 14                      Kunze Inc   34406.54
# 15          Kuphal, Zieme and Kub   27031.86
# 16  Senger, Upton and Breitenberg   29577.46
# 17     Volkman, Goyette and Lemke   32006.87
# 18                  Waelchi-Fahey   28968.68
# 19                  Waters-Walker   36778.96

# %%
x = new_df['name']
y = new_df['net_price']
plt.figure(figsize=(20, 7))
plt.xticks(ticks=list(range(20)), labels=x, rotation = 'vertical',  size=14, color='red')# upper-case
plt.xlabel('Name', size=20, color='steelblue', weight='bold')
plt.ylabel('Total Sales', size=20, color='steelblue', weight='bold')
plt.title('Total Sales by Each Customer', size=20)
plt.bar(x, y)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# ## Assignment II Part 5

# %%
#Let the X-axis and Y-axis data points be as the following:
x = [1, 2, 3,4]
y = [20, 21, 20.5, 20.8]

# %%
plt.plot(x, y)

# %%
plt.figure(figsize=(4,5), dpi=100)
plt.plot(x,y)
er = [0.12, 0.13, 0.2, 0.1]
plt.errorbar(x, y, er)
plt.xlabel('X-Axis', size=14)
plt.ylabel('Y-Axis', size=14)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
#Draw a Scatter Graph with 50 random values:
# Reating random seed for rand-generator
np.random.seed(19680801)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (50 * np.random.rand(N))**2 
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
#Create a data-frame with data:
d = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
'female': [0, 1, 1, 0, 1],
'age': [42, 52, 36, 24, 73],
'preTestScore': [4, 24, 31, 2, 3],
'postTestScore': [25, 94, 57, 62, 70]}
cust_df = pd.DataFrame(data=d)

# %%
cust_df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %%
x = cust_df['preTestScore']
y = cust_df['postTestScore']

# %%
area = cust_df['age'] #Area is determined by age
colors = 'green'
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter Plot with pre-test scores and post-stest scores')
plt.xlabel('pre-test scores')
plt.ylabel('post-test scores')
plt.show()

# %%
#Draw a Scatterplot from the data in question 9 of preTestScore and
#postTestScore with the size = 300 and the color determined by sex

area = cust_df['age'] #Area is determined by age
colors = cust_df['female'] #Determined by sex
colors_lst = []
for i in colors:
    if i == 1:
        colors_lst.append('green')
    if i == 0:
        colors_lst.append('blue')


plt.figure(figsize=(4,5), dpi=300)
plt.scatter(x, y, s=area, c='green', alpha=0.5)
plt.title('Scatter Plot with pre-test scores and post-stest scores')
plt.xlabel('pre-test scores')
plt.ylabel('post-test scores')
plt.show()
